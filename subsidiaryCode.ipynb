# %%
import random as r
import matplotlib.pyplot as plt

# %%
#order and plot a list
ll1 = [r.random() for i in range(10)]
ll2 = [r.random() for i in range(10)]

# %%
ll1.sort()

# %%
ll2.sort()
ll2.reverse()

# %%
plt.plot(ll1)
plt.plot(ll2)
